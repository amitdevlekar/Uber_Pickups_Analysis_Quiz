# %%
import pandas as pd
df=pd.read_csv('C:/Users/User/Downloads/Data Science Certification - February 2023/Python Project/Jupyter code/Project Uber Trips Analysis 20 July 23/uber-raw-data-aug14.csv')

df.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  8/1/2014 0:03:00  40.7366 -73.9906  B02512
# 1  8/1/2014 0:09:00  40.7260 -73.9918  B02512
# 2  8/1/2014 0:12:00  40.7209 -74.0507  B02512
# 3  8/1/2014 0:12:00  40.7387 -73.9856  B02512
# 4  8/1/2014 0:12:00  40.7323 -74.0077  B02512

# %% [markdown]
# Q1. On what date did we see the most number of Uber pickups?
# Skill Test: Grouping & Counting
#
# #Convert the 'Date/Time' column to datetime format
# #Group by date and count the number of pickups
# #Find the date with the highest number of pickups

# %%
import pandas as pd
import numpy as np

# Convert the 'Date/Time' column to datetime format
df['Date/Time'] = pd.to_datetime(df['Date/Time'])
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829275 entries, 0 to 829274
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date/Time  829275 non-null  datetime64[ns]
#  1   Lat        829275 non-null  float64
#  2   Lon        829275 non-null  float64
#  3   Base       829275 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 25.3+ MB

# %%
# Group by date and count the number of pickups
pickups_by_date = df.groupby(df['Date/Time'].dt.date).size()
result=pickups_by_date.idxmax()
print(result)
print("Date with the most number of Uber pickups: ", result)
print("Value : ", pickups_by_date.max())
# Out:
# 2014-08-07
# Date with the most number of Uber pickups:  2014-08-07
# Value :  32759

# %% [markdown]
# Q.2 How many Uber pickups were made on the date with the highest number of pickups? Skill Test: Indexing and filtering
#
# #Filter the DataFrame to include only the rows for the date with the highest number of pickups
#
# #Get the count of pickups on the highest date

# %%
# Find the date with the highest number of pickups

print("Number of pickups on the date with the highest number of pickups:",pickups_by_date.max() )
# Out:
# Number of pickups on the date with the highest number of pickups: 32759

# %% [markdown]
# Q.3 How many unique TLC base companies are affiliated with the Uber pickups in the dataset?
# Skill Test: Counting unique values
#
# #Count the number of unique TLC base companies

# %%
print("Number of unique TLC base companies:",df['Base'].nunique() )
# Out:
# Number of unique TLC base companies: 5

# %% [markdown]
# Q.4 Which TLC base company had the highest number of pickups?
# Skill Test: Grouping, counting, and finding the maximum
#
# #Group by TLC base company and count the number of pickups
#
#
# #Find the TLC base company with the highest number of pickups

# %%
pickups_by_company=df.groupby('Base').size()
print(pickups_by_company.max())
result=pickups_by_company.idxmax()

print("TLC base company with the highest number of pickups: ", result)
# Out:
# 355803
# TLC base company with the highest number of pickups:  B02617

# %%
df['Base'].value_counts().idxmax()
# Out:
# 'B02617'

# %% [markdown]
# Q.5 How many Uber pickups were made at each unique TLC base company?
# Skill Test: Grouping and counting
# #Group by TLC base company and count the number of pickups

# %%
df.groupby('Base').size()
# Out:
# Base
# B02512     31472
# B02598    220129
# B02617    355803
# B02682    173280
# B02764     48591
# dtype: int64

# %% [markdown]
# Q.6 Can you determine the busiest time of day for Uber pickups based on the date/time column?
# Skill Test: Extracting time components, grouping, counting, and finding the maximum
#
# #Extract the hour from the 'Date/Time' column
#
# #Group by hour and count the number of pickups
#
# #Find the hour with the highest number of pickups

# %%
#Extract the hour from the 'Date/Time' column
df['Hour'] = df['Date/Time'].dt.hour

#Group by hour and count the number of pickups
pickups_by_hour = df.groupby(df['Hour']).size()

#Find the hour with the highest number of pickups
result=pickups_by_hour.idxmax()


print("Busiest time of the day for Uber pickups (hour):", result)
# Out:
# Busiest time of the day for Uber pickups (hour): 17

# %% [markdown]
# Q.7 Can you create a visualization (e.g., a bar chart or line plot) to represent the number of Uber pickups over time?
# Skill Test: Data Visualization using Plotting function
#
# import matplotlib.pyplot as plt
#
# #Group by date and count the number of pickups
#
# #Create a line plot to visualize the number of pickups over time

# %%
import matplotlib.pyplot as plt

pickups_by_date = df.groupby(df['Date/Time'].dt.date).size()


pickups_by_date.plot(kind ='line', figsize = (10,6))
# Out:
# <Axes: xlabel='Date/Time'>

# %% [markdown]
# Q8. Can you create a scatter plot to visualize the distribution of Uber pickups based on latitude and longitude?
# Skill Test: Scatter Plot
#
# #Create a scatter plot to visualize the distribution of Uber pickups based on latitude and longitude

# %%
plt.figure(figsize =(10,6))
plt.scatter(df['Lon'], df['Lat'], s =10, alpha=0.3, color='red')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(10,6))
plt.scatter(df['Lon'], df['Lat'], s =10, alpha=0.3, color='red')
plt.xlabel('Longitude')
plt.ylabel("Latitude")
plt.title("Distribution of Uber pickups by Lat & Long")
# Out:
# Text(0.5, 1.0, 'Distribution of Uber pickups by Lat & Long')

# %% [markdown]
# Q9. Can you create a bar chart to compare the number of Uber pickups for each TLC base company?
# Skill Test: Bar Chart
#
# #Create a bar chart to compare the number of Uber pickups for each TLC base company

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

pickups_by_base = df.groupby('Base').size()
plt.figure(figsize = (10,6))
plt.bar(pickups_by_base.index, pickups_by_base.values, alpha =0.7, color='red')
plt.xlabel("TLC Base Company")
plt.ylabel("Numbers of UBR pickups")
plt.title("Numbers of pickups by TLC Base Company")
# Out:
# Text(0.5, 1.0, 'Numbers of pickups by TLC Base Company')

# %% [markdown]
# Q10. Can you create a pie chart to display the percentage distribution of Uber pickups for each day of the week?
# Skill Test: Pie Chart
#
# #Group by day of the week and count the number of pickups
#
# #Create a pie chart to display the percentage distribution of Uber pickups for each day of the week

# %%
pickups_by_day=df['Date/Time'].dt.day_name().value_counts()
print(pickups_by_day)

plt.figure(figsize=(10,6))
plt.pie(x=pickups_by_day.values, labels=pickups_by_day.index, autopct='%1.1f%%', startangle=90)
plt.title('Percentage Distribution of UBR pickups by day of the week')
# Out:
# Date/Time
# Friday       148674
# Saturday     132225
# Thursday     124117
# Wednesday    115256
# Sunday       110246
# Tuesday      107124
# Monday        91633
# Name: count, dtype: int64
# Text(0.5, 1.0, 'Percentage Distribution of UBR pickups by day of the week')
